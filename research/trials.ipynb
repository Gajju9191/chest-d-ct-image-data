# %%
print("ok")
# Out:
# ok

# %% [markdown]
# ## configbox/common.py

# %%
import yaml

# Specify the path to your YAML file
yaml_file_path = 'test.yaml'

# Open the YAML file and load its contents
with open(yaml_file_path, 'r') as yaml_file:
    data = yaml.safe_load(yaml_file)

# Now you can work with the data loaded from the YAML file
print(data)
print(type(data))
# Out:
# {'name': 'Gajju', 'place': 'Pune'}
# <class 'dict'>

# %%
data['name']
# Out:
# 'Gajju'

# %%
data.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data.name
#
# AttributeError: 'dict' object has no attribute 'name'

# %%
from box import ConfigBox

# %%
data
# Out:
# {'name': 'Gajju', 'place': 'Pune'}

# %%
obj = ConfigBox(data)  # now it has became configbox from dictionary
obj
# Out:
# ConfigBox({'name': 'Gajju', 'place': 'Pune'})

# %%
obj.name
# Out:
# 'Gajju'

# %% [markdown]
# ## ensure_annotations

# %%
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x = 2, y = 4)
# Out:
# 8

# %%
get_product(x = 2, y = "4")
# Out:
# '44'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x = 2, y = 4)
# Out:
# 8

# %%
get_product(x = 2, y = "4")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 get_product(x = 2, y = "4")
#
# File c:\Users\Dell\anaconda3\envs\chestd\Lib\site-packages\ensure\main.py:803, in WrappedFunction.__call__(self, *args, **kwargs)
#     798     if not isinstance(value, templ):
#     799         msg = (
#     800             "Argument {arg} of type {valt} to {f} "
#     801             "does not match annotation type {t}"
#     802         )
# --> 803         raise EnsureError(msg.format(
#     804             arg=arg, f=self.f, t=templ, valt=type(value)
#     805         ))
#     807 return self.f(*args, **kwargs)
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x000002DF842C47C0> does not match annotation type <class 'int'>

# %%
# In short ensure_annotations is  bug free function

# decorator is for detecting error

# %% [markdown]
# ## download data from google drive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1IOrIdE5gXq9aiE_aELgVcujOIrpt5ZTh/view?usp=sharing"

# %%
type(url)
# Out:
# str

# %%
url.split("/")
# Out:
# ['https:',
#  '',
#  'drive.google.com',
#  'file',
#  'd',
#  '1IOrIdE5gXq9aiE_aELgVcujOIrpt5ZTh',
#  'view?usp=sharing']

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1IOrIdE5gXq9aiE_aELgVcujOIrpt5ZTh'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "chest-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1IOrIdE5gXq9aiE_aELgVcujOIrpt5ZTh
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1IOrIdE5gXq9aiE_aELgVcujOIrpt5ZTh&confirm=t&uuid=34acab56-9296-4e76-8fbb-09bd5053eb24
# To: c:\Users\Dell\OneDrive\Desktop\chest-data\chest-d-ct-image-data\research\chest-data.zip
# 100%|██████████| 49.0M/49.0M [00:04<00:00, 10.0MB/s]
# 'chest-data.zip'

# %%
# we can't read the data directly from gdrive.
# that's why we have to download the data.
